# %% [markdown]
# # **INDIAN CUSINE ANALYSIS**
#
# **(TOP 255 FOODS OF INDIA)**

# %% [markdown]
# ![feature-platter.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **INTRODUCTION**
#
#  **Indian Cuisine** consists of a variety of regional and traditional
#
# cuisines native to the Indian Subcontinent. Given the diversity in soil,
#
# climate, culture, ethnic groups, and occupations, these cuisines vary
#
# substantially and use locally available spices, herbs, vegetables, and
#
# fruits. Indian food is also heavily influenced by religion, cultural
#
# choices and traditions. Historical events such as invasions, trade
#
# relations, and colonialism have played a role in introducing certain foods
#
# to this country.
#
#
#  The cuisine of India is one of the world's most diverse cuisines,
#
# characterized by its sophisticated and subtle use of the many spices,
#
# vegetables, grains and fruits grown across India. The cuisine of each
#
# geographical region includes a wide assortment of dishes and cooking
#
# techniques reflecting the varied demographics of the ethnically diverse
#
# Indian subcontinent.
#
#  This notebook comprises of some interesting facts and observations that people might not know about Indian cuisine.

# %% [markdown]
# # **Table of Contents**:
#
# * About the Dataset
# * Importing the necessary Libraries
# * Correlating the Numerical Values in the Dataset
# * Unique Foods in the Top indian foods
# * Vegetarian and Non-Vegetarian dishes
# * Number of dishes based on regions
# * State-wise Distribution of Indian Foods
# * Proportion of Flavor Profiles
# * Ingredients used in Indian main course
# * Ingredients used in Indian desserts
# * List of Indian dishes that are sweet in flavor but not desserts
# * Ingredients used in South-Indian cuisine
# * Ingredients used in North-Indian cuisine
# * Overall Ingredients used in Indian cuisine
# * Mostly used Ingredients Combinations in Foods
# * Comparing Preparation time and Cooking time
# * Comparing Preparation time and Cooking time for Veg and Non-veg dishes
# * Ingredients used in Vegetarian food
# * Ingredients used in Non Vegetarian food
# * Top 10 snacks with shortest cooking time
# * Top 10 snacks with longest cooking time
# * Top 10 main courses with shortest cooking time
# * Top 10 main courses with Longest cooking time

# %% [markdown]
# ## **About the Dataset:**
#
# The dataset consists of about **255** Indian dishes and **9** columns associated with each of them.
#
# The **9** columns are as follows:-
#
# **Name** : name of the dish
#
# **Ingredients** : main ingredients used
#
# **Diet** : type of diet - either vegetarian or non vegetarian
#
# **Prep_time** : preparation time
#
# **Cook_time** : cooking time
#
# **Flavor_profile** : flavor profile includes whether the dish is spicy, sweet, bitter, etc
#
# **Course** : course of meal - starter, main course, dessert, etc
#
# **State** : state where the dish is famous or is originated
#
# **Region** : region where the state belongs

# %% [markdown]
# ## **Importing the necessary Libraries:**

# %%
import numpy as np
import pandas as pd
# !pip install geopandas
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline
import random
# !pip install --upgrade plotly
# !pip install jupyter-dash
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.colors import n_colors
from plotly.subplots import make_subplots
init_notebook_mode(connected=True)
import cufflinks as cf
cf.go_offline()
from wordcloud import WordCloud , ImageColorGenerator
from PIL import Image
# !python3.7 -m pip install --upgrade pip
# !pip install pywaffle
from pywaffle import Waffle 
import seaborn as sns

# %%
#Reading the filepath
df=pd.read_csv("/content/drive/MyDrive/indian_food.csv")

# %%
#ckecking the top 5 of the given data 
df.head()
# Out:
#              Name  ... Region
# 0      Balu shahi  ...   East
# 1          Boondi  ...   West
# 2  Gajar ka halwa  ...  North
# 3          Ghevar  ...   West
# 4     Gulab jamun  ...   East
#
# [5 rows x 9 columns]

# %%
# Relevant info about all the attributes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            255 non-null    object
#  1   Ingredients     255 non-null    object
#  2   Diet            255 non-null    object
#  3   Prep_time       255 non-null    int64
#  4   Cook_time       255 non-null    int64
#  5   Flavor_profile  255 non-null    object
#  6   Course          255 non-null    object
#  7   State           255 non-null    object
#  8   Region          255 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 18.1+ KB

# %%
#checking for null values , so if any found will further clean the data
df.isna().sum()
# Out:
# Name              0
# Ingredients       0
# Diet              0
# Prep_time         0
# Cook_time         0
# Flavor_profile    0
# Course            0
# State             0
# Region            0
# dtype: int64

# %%
#Description of the dataset
df.describe()
# Out:
#         Prep_time   Cook_time
# count  255.000000  255.000000
# mean    33.203922   37.596078
# std     72.162366   46.906063
# min      5.000000    2.000000
# 25%     10.000000   20.000000
# 50%     10.000000   30.000000
# 75%     20.000000   40.000000
# max    500.000000  720.000000

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# ## **Correlating the Numerical Values in the Dataset**

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr())

# %% [markdown]
# ## **Insights:**
# The dataset has no null values surprisingly !

# %%
#shape of the dataset
df.shape
# Out:
# (255, 9)

# %% [markdown]
# ## **Unique Foods in the Top indian foods**

# %%
#Unique Food items
df["Name"].unique()
# Out:
# array(['Balu shahi', 'Boondi', 'Gajar ka halwa', 'Ghevar', 'Gulab jamun',
#        'Imarti', 'Jalebi', 'Kaju katli', 'Kalakand', 'Kheer', 'Laddu',
#        'Lassi', 'Nankhatai', 'Petha', 'Phirni', 'Rabri', 'Sheera',
#        'Singori', 'Sohan halwa', 'Sohan papdi', 'Chhena jalebi',
#        'Chhena kheeri', 'Chhena poda', 'Cham cham', 'Kheer sagar',
#        'Ledikeni', 'Lyangcha', 'Malapua', 'Mihidana', 'Misti doi',
#        'Pantua', 'Pithe', 'Rasabali', 'Ras malai', 'Rasgulla', 'Sandesh',
#        'Adhirasam', 'Ariselu', 'Bandar laddu', 'Chikki', 'Dharwad pedha',
#        'Double ka meetha', 'Gavvalu', 'Kakinada khaja', 'Kuzhi paniyaram',
#        'Mysore pak', 'Obbattu holige', 'Palathalikalu', 'Poornalu',
#        'Pongal', 'Pootharekulu', 'Qubani ka meetha', 'Sheer korma',
#        'Unni Appam', 'Kajjikaya', 'Anarsa', 'Basundi', 'Dhondas',
#        'Doodhpak', 'Mahim halwa', 'Modak', 'Shankarpali', 'Shrikhand',
# ...

# %%
df["Name"].nunique()
# Out:
# 255

# %% [markdown]
# ## **Insights:**
#  All the observations in this notebook are based on these 255 dishes. There are many more dishes in Indian Cuisine!

# %%
df.sample()
# Out:
#               Name  ... Region
# 196  Methi na Gota  ...   West
#
# [1 rows x 9 columns]

# %% [markdown]
# ## **Vegetarian and Non-Vegetarian dishes**

# %%
#pie chart for vegetarian and non-vegetarian dishes 
df.plot(figsize=(8,8))
df['Diet'].value_counts().plot(kind='pie',autopct='%1.1f%%',explode=[0.1]*2,shadow=True)

# %% [markdown]
# ## **Insights:**
#
#
# Vegetarian dishes are more than Non Vegetarian dishes

# %% [markdown]
# **Fun fact :**
#
#  India ranked top in the world with 38% of the total population being vegetarians

# %% [markdown]
# ## **Number of dishes based on regions**

# %%
#region plot using pie chart
reg_count=df["Region"].value_counts()
pie, ax = plt.subplots(figsize=[10,8])
labels = reg_count.keys()
plt.pie(x=reg_count, autopct="%.1f%%", explode=[0.05]*6, labels=labels, pctdistance=0.5)
plt.title("Region Wise Dishes", fontsize=14);

# %% [markdown]
# # **Dishes based on the Course**

# %%
#Unique courses
df["Course"].unique()
# Out:
# array(['dessert', 'main course', 'starter', 'snack'], dtype=object)

# %%
course_df = df.Course.value_counts().reset_index()
course_df.columns = ['Course','count']
course_df = course_df.sample(frac=1)
sns.barplot(x = 'Course',
            y = 'count',
            data = course_df)

# %% [markdown]
# ## **Insights:**
# Courses are categorised into 4 different types among that Main courses and Dessert counts stand high.

# %% [markdown]
# ## **State-wise Distribution of Indian Foods**

# %%
#State wise overall courses distribution
shp_gdf = gpd.read_file('/content/drive/MyDrive/1st Sem Project/Indian_')
course_region = df
course_region_df = course_region.State.value_counts().reset_index()
course_region_df.columns = ['State','count']
merged = shp_gdf.set_index('st_nm').join(course_region_df.set_index('State'))
fig, ax = plt.subplots(1, figsize=(10, 10))
ax.axis('off')
ax.set_title('State-wise Distribution of Indian Foods',
             fontdict={'fontsize': '15', 'fontweight' : '3'})
fig = merged.plot(column='count', cmap='PiYG', linewidth=0.5, ax=ax, edgecolor='0.2',legend=True)

# %%
#state wise distribution of indian sweets
shp_gdf = gpd.read_file('/content/drive/MyDrive/1st Sem Project/Indian_')
desserts = df[df['Course']=='dessert']
des_df = desserts.State.value_counts().reset_index()
des_df.columns = ['State','count']
merged = shp_gdf.set_index('st_nm').join(des_df.set_index('State'))
fig, ax = plt.subplots(1, figsize=(10, 10))
ax.axis('off')
ax.set_title('State-wise Distribution of Indian Sweets',
             fontdict={'fontsize': '15', 'fontweight' : '3'})
fig = merged.plot(column='count', cmap='Paired', linewidth=0.5, ax=ax, edgecolor='0.2',legend=True)

# %%
course_df
# Out:
#         Course  count
# 2        snack     39
# 0  main course    129
# 3      starter      2
# 1      dessert     85

# %% [markdown]
# ## **Insights :**
#
# About 129 dishes are preferably eaten as a main course

# %% [markdown]
# # **Proportion of Flavor Profiles**

# %%
data = dict(df['Flavor_profile'].value_counts(normalize = True) * 100)

flavor = ['spicy','sweet','bitter','sour'] 
            

fig = plt.figure( 
    rows=10,
    columns=11,
    FigureClass = Waffle, 
    values = data, 
    title={'label': 'Proportion of Flavor Profiles', 'loc': 'center',
          'fontsize':21},
    colors=("#FF7F0E", "#00B5F7", "#AB63FA","#00CC96"),
    labels=[f"{k} ({v:.2f}%)" for k, v in data.items()],
    legend={'loc': 'lower left', 'bbox_to_anchor': (0, -0.2), 'ncol': len(data), 'framealpha': 0},
    figsize=(8,8)
)
# Out:
# <Waffle size 576x576 with 1 Axes>

# %% [markdown]
# ## **Insights :**
#
#   *  More than 58% of the dishes are spicy in flavour
#
#   *  Least number of dishes are sour in flavor

# %% [markdown]
# ## **Fun fact :**
# India is the largest producer of spices in the world. No country in the world produces as many varieties of spices as India.
#
# According to Ayurveda, Indian food is a balance of 6 flavors: sweet, sour, salty, bitter, spicy, and astringent. Each flavor is
#
# imparted from a particular ingredient in a dish. This is the uniqueness of Indian cuisine!

# %% [markdown]
# ## **Ingredients used in Indian main course**

# %% [markdown]
# Commonly used ingredients in South-Indian cuisine are ***Garam Masala , Ginger ,Tomato , Coconut, Rice.***

# %%
dessert_df  = df[df['Course']=='main course'].reset_index()

ingredients = []
for i in range(0,len(dessert_df)):
    text = dessert_df['Ingredients'][i].split(',')
    text = ','.join(text)
    ingredients.append(text)
    text = ' '.join(ingredients)

wordcloud = WordCloud(width = 400, height = 400, colormap = 'copper_r'
                      ,background_color ='white', 
                min_font_size = 8).generate(text)                  
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis('off') 
plt.show()

# %% [markdown]
# ## **Ingredients used in Indian desserts**

# %%
dessert_df  = df[df['Course']=='dessert'].reset_index()

ingredients = []
for i in range(0,len(dessert_df)):
    text = dessert_df['Ingredients'][i].split(',')
    text = ','.join(text)
    ingredients.append(text)
    text = ' '.join(ingredients)

wordcloud = WordCloud(width = 400, height = 400, colormap = 'cool_r'
                      ,background_color ='white', 
                min_font_size = 8).generate(text)                  
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis('off') 
plt.show()

# %% [markdown]
# ## **Insights:**
# Commonly used ingredients in making Indian sweets are **Sugar, Ghee,Floor, Milk, Rice**

# %% [markdown]
# ## **List of Indian dishes that are sweet in flavor but not desserts**

# %%
sweet_df = df[df['Flavor_profile']=='sweet']
final_sweet_df = sweet_df[sweet_df['Course']!='dessert']
final_sweet_df
# Out:
#                    Name  ...      Region
# 46       Obbattu holige  ...       South
# 85         Dal makhani   ...       North
# 150       Paruppu sadam  ...       South
# 171              Bhakri  ...        West
# 222                Khar  ...  North East
# 243  Mishti Chholar Dal  ...        East
# 244             Pakhala  ...        East
# 245          Pani Pitha  ...  North East
#
# [8 rows x 9 columns]

# %% [markdown]
# ## **Ingredients used in South-Indian cuisine**

# %%
south_df = df[df['Region']=='South'].reset_index()

ingredients = []
for i in range(0,len(south_df)):
    text = south_df['Ingredients'][i].split(',')
    text = ','.join(text)
    ingredients.append(text)
    text = ' '.join(ingredients)
    
wordcloud = WordCloud(width = 400, height = 400, colormap = 'hot_r'
                      ,background_color ='white', 
                min_font_size = 10).generate(text)                  
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis('off') 
plt.show()

# %% [markdown]
# ## **Insights:**
# Commonly used ingredients in South-Indian cuisine are **Urad Dal, Curry leaves, Coconut, Rice.**

# %% [markdown]
# ## **Ingredients used in North-Indian cuisine**

# %%
north_df = df[df['Region']=='North'].reset_index()

ingredients = []
for i in range(0,len(north_df)):
    text = north_df['Ingredients'][i].split(',')
    text = ','.join(text)
    ingredients.append(text)
    text = ' '.join(ingredients)

wordcloud = WordCloud(width = 400, height = 400, colormap = 'winter',
                      background_color ='white', 
                min_font_size = 10).generate(text)                  
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis('off') 
plt.show()

# %% [markdown]
# ## **Insights:**
# Commonly used ingredients in North Indian cuisine are **Garam Masala, Ginger, Flour, Chickpeas.**

# %% [markdown]
# ## **Overall Ingredients used in Indian cuisine**

# %%
Ingredients = []
for i in range(0,len(df)):
    text = df['Ingredients'][i].split(',')
    text = ','.join(text)
    ingredients.append(text)
    text = ' '.join(ingredients)

india_coloring = np.array(Image.open('/content/drive/MyDrive/1st Sem Project/triclr.jpg'))

wc = WordCloud(background_color="black", width = 150, height = 600,mask=india_coloring,min_font_size=8)
wc.generate(text)

image_colors = ImageColorGenerator(india_coloring)

plt.figure(figsize = (10,10))
plt.imshow(wc.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ## **Insights:**
# The overall ingredients used in the topp 255 foods of India are shown above.

# %% [markdown]
# ## **Mostly used Ingredients Combinations in Foods**

# %%
df["Ingredients"].value_counts()
# Out:
# Chhena, sugar, ghee                                                                 2
# Gram flour, ghee, sugar                                                             2
# Arbi ke patte, sesame seeds, gur, bengal gram flour, imli                           2
# Rice flour, jaggery, ghee                                                           1
# Cauliflower, potato, garam masala, turmeric, curry leaves                           1
#                                                                                    ..
# Moong dal, garam masala powder, garlic, green chilli, all purpose flour             1
# Green beans, bitter gourd, ridge gourd, banana, brinjal                             1
# Condensed milk, nestle cream, coconut ice, red food coloring, desiccated coconut    1
# Bottle gourd, coconut oil, garam masala, ginger, green chillies                     1
# Milk, sugar, saffron, cardamom                                                      1
# ...

# %%
plt.figure(figsize=(15,8))
loc=df['Ingredients'].value_counts()[0:10]
sns.barplot(x=loc,y=loc.index,palette='deep')

# %% [markdown]
# ## **Insights:**
# So, the mostly used ingredients in the Foods are

# %% [markdown]
# ## **Comparing Preparation time and Cooking time**

# %%
#comparing preparation and cooking time using plots
plt.figure(figsize = (8,6))
print(df.Prep_time.plot())
print(df.Cook_time.plot())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#Checking the outlier foods by cooking and preparation time
df.plot(kind='box',figsize = (8,6))

# %% [markdown]
# ## **Comparing Preparation time and Cooking time for Veg and Non-veg dishes**

# %%
plt.figure(figsize = (8,6))
diet =sns.scatterplot(x="Cook_time", y="Prep_time",hue="Diet",data=df);

# %%
#Outlier foods by cooking time
df[df["Cook_time"]>=100]
# Out:
#             Name  ... Region
# 27       Malapua  ...  North
# 62     Shrikhand  ...   West
# 75       Biryani  ...  South
# 114  Pindi chana  ...  North
#
# [4 rows x 9 columns]

# %%
#Outlier foods by Preparation time
df[df["Prep_time"]>=300]
# Out:
#             Name  ... Region
# 29     Misti doi  ...   East
# 114  Pindi chana  ...  North
# 128         Dosa  ...  South
# 130         Idli  ...  South
# 144  Masala Dosa  ...  South
# 155        Puttu  ...  South
#
# [6 rows x 9 columns]

# %% [markdown]
# # **Insights:**
#
# * Most of the dishes **vegeterian** as well as **non-vegeterian** have preparation time and cooking time between 0 to 100 minutes.
#
# * **Shrikhand** which is a traditional **Maharashtian** sweet has cooking time of 720 minutes mainly because the sweet has to be kept in the refrigerator for it to set.
# * **Pindi Chana** is a famous main course item in the **North India** which takes **500** minutes to prepare. The reason behind this is that the Chana needs to be soaked for about **7-8** hours.

# %% [markdown]
# ## **Ingredients used in Vegetarian food**

# %%
def green_color_func(word, font_size, position, orientation, random_state=None,
                    **kwargs):
    return "hsl(100, 100%%, %d%%)" % random.randint(20, 40)


veg_df = df[df['Diet']=='vegetarian'].reset_index()

ingredients = []
for i in range(0,len(veg_df)):
    text = veg_df['Ingredients'][i].split(',')
    text = ','.join(text)
    ingredients.append(text)
    text = ' '.join(ingredients)

wordcloud = WordCloud(width = 400, height = 400, background_color ='white', 
                min_font_size = 10).generate(text)                  
plt.figure(figsize = (8, 8), facecolor = None) 

default_colors = wordcloud.to_array()
plt.imshow(wordcloud.recolor(color_func=green_color_func, random_state=3),
           interpolation="bilinear")

plt.axis('off') 
plt.show()

# %% [markdown]
# ## **Fun fact :**
# India has the world’s second-lowest rates of meat consumption per person. Yet the majority of the country does not follow a **vegetarian diet**, as commonly believed. As per a survey released by the government of India, only about **29**% of the country’s population follows a vegetarian diet.

# %% [markdown]
# ## **Ingredients used in Non Vegetarian food**

# %%
#Ingredients used in Non-Veg food
def red_color_func(word, font_size, position, orientation, random_state=None,
                    **kwargs):
    return "hsl(0, 100%%, %d%%)" % random.randint(30, 50)


nveg_df = df[df['Diet']=='non vegetarian'].reset_index()

ingredients = []
for i in range(0,len(nveg_df)):
    text = nveg_df['Ingredients'][i].split(',')
    text = ','.join(text)
    ingredients.append(text)
    text = ' '.join(ingredients)

wordcloud = WordCloud(width = 400, height = 400, background_color ='white', 
                min_font_size = 10).generate(text)                  
plt.figure(figsize = (8, 8), facecolor = None) 

default_colors = wordcloud.to_array()
plt.imshow(wordcloud.recolor(color_func=red_color_func, random_state=3),
           interpolation="bilinear")

plt.axis('off') 
plt.show()

# %% [markdown]
# ## **Insights:**
#  In Non-Vegetarian dishes, most commonly used ingredients are **Chicken** and **Fish** for obvious reasons. Along with that some spices can also be seen such as **garam masala, cinnamon, chillies, etc.** These are generally used for marination purposes.

# %% [markdown]
# ## **Top 10 snacks with shortest cooking time**

# %%
plt.figure(figsize = (8,6))
snack_df = df[df['Course']=='snack']
t10_snacks=snack_df.head(10).sort_values(by='Cook_time',ascending=True)
sns.barplot(x = 'Cook_time', y = 'Course', hue = 'Name', data = t10_snacks)

# %% [markdown]
# ## **Insights:**
# **Pani puri** is the shortest cooking time food.

# %% [markdown]
# ## **Top 10 snacks with longest cooking time**

# %%
plt.figure(figsize = (8,6))
snack_df = df[df['Course']=='snack']
t10_snacks=snack_df.tail(10).sort_values(by='Cook_time',ascending=True)
sns.barplot(y = 'Course', x = 'Cook_time', hue = 'Name', data = t10_snacks)

# %% [markdown]
# ## **Insights:**
#  The snacks with longest time for cooking is **Patra.**

# %% [markdown]
# ## **Top 10 main courses with shortest cooking time**

# %%
plt.figure(figsize = (8,6))
snack_df = df[df['Course']=='main course']
t10_snacks=snack_df.head(10).sort_values(by='Cook_time',ascending=True)
sns.barplot(y = 'Course', x = 'Cook_time', hue = 'Name', data = t10_snacks)

# %% [markdown]
# ## **Insights:**
# The main course with shortest cooking time is **Galho**

# %% [markdown]
# ## **Top 10 main courses with Longest cooking time**

# %%
plt.figure(figsize = (8,6))
snack_df = df[df['Course']=='main course']
t10_snacks=snack_df.tail(10).sort_values(by='Cook_time',ascending=True)
sns.barplot(y = 'Course', x = 'Cook_time', hue = 'Name', data = t10_snacks)

# %% [markdown]
# ## **Insights**:
#  Main course with Longest cooking time is Red Rice.

# %% [markdown]
# # **Conclusion:**
# In this top **256** foods of **India** , from the dataset that I have prepared I came to an Conclusion which are the following:
#  * All the foods have unique name.
#  * Most of the Top foods are **Vegetarian**.
#  * The region in which we get most of the top foods is **West Region**.
#  * The state in which we get most of the top foods is **Gujarat**.
#  * Most of the foods are **spicy**.
#  * Commonly used ingredients in making Indian sweets are **Sugar, Ghee,Floor, Milk, Rice**
#  * The Preparation time is not same as the **Cooking time**.For some foods it is quite more than cooking.
#
#   So, if we choose a Top food in India it may be a **Veg , Spicy, Maincourse food from the West or South Region.**
#
# ####  **This dataset will be mainly useful for someone who wants to start a Restaurant on the Theme of Indian Cusine.These varieties of food can boost their business with top tastes of Indian Cusine.**
#
# #### **The dataset which I have prepared will also be useful for all the foodies who love the Indian flavours it also helps the tourists and travellers who likes to visit different parts of India with a taste of food that suits them.**
